# %% [markdown]
# DAY 7 - WORKFLOWS & JOB ORCHESTRATION

# %%
dbutils.widgets.text("run_date","2026-01-15")
run_date = dbutils.widgets.get("run_date")

print(f"Running Bronze layer for date: {run_date}")
# Out:
# Running Bronze layer for date: 2026-01-15
